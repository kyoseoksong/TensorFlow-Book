# %%
import tensorflow as tf

filenames = tf.train.match_filenames_once('./audio_dataset/*.wav') # 패턴 매칭되는 파일명을 저장합니다
count_num_files = tf.size(filenames)
filename_queue = tf.train.string_input_producer(filenames) # 랜덤하게 파일명을 검색하기 위한 파이프라인을 설정합니다
reader = tf.WholeFileReader() # 텐서플로우에서 원시적으로 파일을 읽습니다
filename, file_contents = reader.read(filename_queue) # 파일 데이터를 추출하기 위해 reader를 실행합니다

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_files = sess.run(count_num_files) # 파일의 수를 셉니다
    
    coord = tf.train.Coordinator() # 파일명 큐를 위해 쓰레드를 초기화합니다
    threads = tf.train.start_queue_runners(coord=coord)
    
    for i in range(num_files): # 데이터를 하나씩 반복합니다
        audio_file = sess.run(filename)
        print(autio_file)
# Out:
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# ~/code/rl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# ~/code/rl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#
# ~/code/rl/lib/python3.5/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#
# ...
